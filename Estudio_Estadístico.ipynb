# %% [markdown]
# <a href="https://colab.research.google.com/github/Laurita274/Analisis_de_estadisticas/blob/main/Estudio_Estad%C3%ADstico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ** Análisis estadistico de la encuenta de requerminientos, con valores cerrados, de una muestra de problacion **

# %% [markdown]
# [texto del enlace](https://)# cargar datos

# %% [markdown]
# ```
# # cargar datos en excel o CSV
# ```
#
# # Paso 1: Cargar Datos

# %%
from google.colab import files
uploaded = files.upload() # este es para que se ejecute una ventana que me permite subir el archivo
# Out:
#      <input type="file" id="files-cfa553fa-eb92-4a3d-bbb0-4c30a2a405d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cfa553fa-eb92-4a3d-bbb0-4c30a2a405d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Carga, inspeccion y limpieza de datos

# %% [markdown]
# Paso 1 importar librerias

# %%
# pandas para trabajar datos de la tabla del excel
import pandas as pd
# numpy para calculoc numericos ( promedios, desviaciones,media, valanza)
import numpy as np
#matplotlib y seaborn: para crear graficas
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # paso 2: carga de archivo en excel
# Leer un archivo en excel  y lo convierte en una tabla de python.
# la tabla se llama DataFrame, el cual es  una hoja de ecel  con filas y columnas.

# %%
# nombre del archivo y pestaña a leer
nombre_archivo ='Validacion_SaaS_Ecommerce_Dashboard.xlsx'
nombre_pestana ='Respuestas_Encuesta'

# cargar los carchivos
df =pd.read_excel(nombre_archivo,sheet_name=nombre_pestana)
# verificar que se cargo los datos correctamente
print(f'archivos cargados: {df.shape[0]} filas y {df.shape[1]} columnas')
# Out:
# archivos cargados: 30 filas y 20 columnas

# %% [markdown]
# # Paso 3: Inspeccion de datos

# %% [markdown]
# ** ¿ Que es lo que hace ?** Muestra como se ven los datos  y que tipo de informacion tiene,
# en este acoso la informacion de los requisitos tomados por parte de los clientes.

# %%
# mostrar las primeras  10 filas
print ('mostar las 10 primeras filas')
df.head(10)
# Out:
# mostar las 10 primeras filas
#    ID Comercio    Nombre Comercio Categoría / Sector Tamaño Inventario (SKUs)  \
# 0            1     Moda Urbana Co               Moda  Mediano (100-1000 SKUs)
# 1            2     TechZone Store         Tecnología      Grande (>1000 SKUs)
# 2            3     Glow Cosmetics            Belleza      Pequeño (<100 SKUs)
# 3            4       NutriOrganic          Alimentos  Mediano (100-1000 SKUs)
# 4            5     Hogar & Decora              Hogar      Grande (>1000 SKUs)
# 5            6     FitSport Store           Deportes  Mediano (100-1000 SKUs)
# 6            7     PetLovers Shop           Mascotas      Pequeño (<100 SKUs)
# 7            8    Kiddos Juguetes         Juguetería  Mediano (100-1000 SKUs)
# 8            9  BookWorm Librería           Librería      Grande (>1000 SKUs)
# 9           10  AutoParts Express         Automotriz      Grande (>1000 SKUs)
#
#                        Canales de Venta  P1_Abandono  \
# ...

# %%
# otra forma
# la otra formas es
print ('______________________________________________________')
display(df.dtypes)
# Out:
# ______________________________________________________
# ID Comercio                  int64
# Nombre Comercio             object
# Categoría / Sector          object
# Tamaño Inventario (SKUs)    object
# Canales de Venta            object
# P1_Abandono                 object
# P2_Impacto1Clic             object
# P3_PagoPref                 object
# P4_Autenticacion            object
# P5_Comision1Clic            object
# P6_NumCanales               object
# P7_FrecOverselling          object
# P8_TiempoActualizacion      object
# P9_Centralizacion           object
# P10_TemorSinc               object
# P11_VentasRecurrentes       object
# P12_Suscripciones           object
# P13_FuncionalidadUpsell     object
# P14_AumentoTicket           object
# P15_PrecioSaaS              object
# dtype: object

# %% [markdown]
# # Paso 4: Buscar problemas en los datos:
# 1. valores nulos
# 2. celdas vacias
# 3. filas duplicadas

# %%
# contar valores nulos por columna
print("valores nulos por columna: ")
nulos =df.isnull().sum()
print(' cantidad de nulos son: ', nulos)
# Out:
# valores nulos por columna:
#  cantidad de nulos son:  ID Comercio                 0
# Nombre Comercio             0
# Categoría / Sector          0
# Tamaño Inventario (SKUs)    0
# Canales de Venta            0
# P1_Abandono                 0
# P2_Impacto1Clic             0
# P3_PagoPref                 0
# P4_Autenticacion            0
# P5_Comision1Clic            0
# P6_NumCanales               0
# P7_FrecOverselling          0
# P8_TiempoActualizacion      0
# P9_Centralizacion           0
# P10_TemorSinc               0
# P11_VentasRecurrentes       0
# P12_Suscripciones           0
# P13_FuncionalidadUpsell     0
# P14_AumentoTicket           0
# P15_PrecioSaaS              0
# dtype: int64

# %%
# contar filas duplicadas
duplicados = df.duplicated().sum()
print("filas duplicadas: ",duplicados)
# Out:
# filas duplicadas:  0

# %% [markdown]
# # Observacion importante:
# 1. si una columna tiene muchos nulos >50%, esta muestra no serviria.
# 2. si es inferior de <50%, **se peude trabajar la muestra**

# %% [markdown]
# # Paso 5: Limpiar los datos
# Elimina espacios de mas al inicio y final  de cada texto. ejemplo " MODA  " se converte en "MODA". esto es necesario por que si tiene espacios, esta palabras no son iguales.

# %%
# Seleccionar columnas de texto
columnas_texto =df.select_dtypes(include='object').columns
# limpiar cada columna
for columna in columnas_texto:
  df[columna] = df[columna].str.strip()
#mostrar reslitado de la limpieza que fue completada
print('limpieza completada')
# Out:
# limpieza completada

# %% [markdown]
# # Estadistica descriptiva

# %% [markdown]
# La estadística descriptiva es la rama de la estadística que se encarga de recolectar, organizar, resumir, analizar y presentar un conjunto de datos numéricos o cualitativos mediante tablas, gráficos y medidas de resumen.
#
# Su objetivo principal es describir y caracterizar el comportamiento de los datos sin realizar inferencias o generalizaciones sobre una población mayor.
#
# # Herramientas principales
#
# **Medidas** de tendencia central: Media, mediana y moda.
#
# **Medidas** de dispersión: Rango, varianza, desviación estándar y coeficiente de variación.
#
# **Medidas de posición**: Cuartiles, deciles y percentiles.
#
# Tablas de frecuencias: Frecuencia absoluta, relativa y acumulada.
#
# Gráficos estadísticos: Histogramas, diagramas de barras, gráficos de sectores (pastel) y diagramas de caja (boxplot).

# %% [markdown]
# # Paso 6: Distribución por sector
# ¿Qué hace? Cuenta cuantos comercios hay en cada sector y calcula el porcentaje

# %%
#value_conts() cuenta las veces que aparece cada valor
# normalize = True  lo converte en porcentaje
tabla_sector =pd.DataFrame({'Cantidad' : df['Categoría / Sector'].value_counts(),'Porcentaje (%)' : (df['Categoría / Sector'].value_counts(normalize=True)*100).round(2)})

print("Distribucion por sector:")
display(tabla_sector)
# Out:
# Distribucion por sector:
#                     Cantidad  Porcentaje (%)
# Categoría / Sector
# Moda                       4           13.33
# Tecnología                 4           13.33
# Belleza                    4           13.33
# Alimentos                  4           13.33
# Hogar                      4           13.33
# Deportes                   2            6.67
# Mascotas                   2            6.67
# Juguetería                 2            6.67
# Librería                   2            6.67
# Automotriz                 2            6.67

# %% [markdown]
# # Paso 7: Tablas cruzadas

# %%
# pd.crosstab() Crea  una tabla que cruza  dos variables
# las filas son sectores ,  las columnas son rangos de precio
crosstab =pd.crosstab(df['Categoría / Sector'],df['P15_PrecioSaaS'],margins=True)
print(" tabla cruzada ver precio por sector")
display(crosstab)
# Out:
#  tabla cruzada vr precio por sector
# P15_PrecioSaaS      $100 - $199 USD/mes  $49 - $99 USD/mes  < $49 USD/mes  \
# Categoría / Sector
# Alimentos                             3                  1              0
# Automotriz                            0                  0              0
# Belleza                               2                  2              0
# Deportes                              1                  1              0
# Hogar                                 1                  1              1
# Juguetería                            0                  1              1
# Librería                              0                  1              1
# Mascotas                              0                  2              0
# Moda                                  2                  1              0
# Tecnología                            4                  0              0
# All                                  13                 10              3
#
# ...

# %% [markdown]
# # Paso 8: KPIs indicarores clave

# %%
# Kpi 1 : % que consedera **ALto** en impacto de pago 1-CLic
#str.contains() busca texto , .mena() calcula promedio, * 100 converte a %
kpi1 =df['P2_Impacto1Clic'].str.contains('Alto|Crítico', case=False, na=False).mean()*100
# KPI 2: % Con problemas de overselling frecuente
kpi2= df['P7_FrecOverselling'].str.contains('Frecuentemente|Diariamente', case=False, na=False).mean()*100
print(f"KPI 1: Impacto 1_clic alto|Crítico {kpi1:.2f}%")
print(f"KPI 2:Overselling Frecuente|Díario {kpi2:.2f}%")
# Out:
# KPI 1: Impacto 1_clic alto|Crítico 76.67%
# KPI 2:Overselling Frecuente|Díario 56.67%

# %% [markdown]
# # Paso 9: Mapa canales
# Que hace? Convierte respuesta de texto a numero para poder hacer calculo . Ejemplo : '3 - 4 canales' se converte en 3.5

# %%
# Diccionario de conversiones
mapa_canales ={'1 canal':1.0, '2 canales':2.0, '3-4 canles':3.5, '5 o mas canaes':5.0}
# aplicar las conversiones
df['NumCanales_Num'] = df['P6_NumCanales'].map(mapa_canales)
#Calcular estadisticas
print(f"Promedio de calanes: {df['NumCanales_Num'].mean():.2f}")
print(f"Mediana de calanes: {df['NumCanales_Num'].median():.2f}")
# Out:
# Promedio de calanes: 1.81
# Mediana de calanes: 2.00

# %% [markdown]
# # Paso 10: Método de pago por sector
# ¿Que hace?
# para cara sector,  encuentra cual es el método de pago más elegido.
# 1. función para obtener la moda de forma segura
# 2. La "moda" es el valor que más se repite

# %%
print("Método de pago mas usado por sector:")
def moda_segura(x):
  m=x.mode()
  return m.iloc[0] if not m.empty else 'sin datos'

# agrupar pro sector y encontrar el método  mas usado
pago_por_sector= df.groupby('Categoría / Sector')['P3_PagoPref'].agg(moda_segura)
print("Método de pago mas usado por sector:")
print(pago_por_sector)
# Out:
# Método de pago mas usado por sector:
# Método de pago mas usado por sector:
# Categoría / Sector
# Alimentos     Tarjeta de crédito/débito guardada
# Automotriz    Tarjeta de crédito/débito guardada
# Belleza       Tarjeta de crédito/débito guardada
# Deportes                    Billeteras digitales
# Hogar         Tarjeta de crédito/débito guardada
# Juguetería                   Transferencia / PSE
# Librería      Tarjeta de crédito/débito guardada
# Mascotas                    Billeteras digitales
# Moda          Tarjeta de crédito/débito guardada
# Tecnología                  Billeteras digitales
# Name: P3_PagoPref, dtype: object

# %% [markdown]
# # Paso 11: Disposicion a pagar por comisión
#
# ¿Que hace?
# Muestra qué porcentaje de comercion aceptaría pagar una comisión extra del 0.5%.

# %%
# value_conunt(normalize =True) calcula proporciones
comision_dist=df['P5_Comision1Clic'].value_counts(normalize=True)*100
print("¿Cuantos aceptaria pagar comisión del 0.5%")
for respuesta, porcentaje in comision_dist.items():
  print(f"{respuesta}: {porcentaje:.1f}%")
# Out:
# ¿Cuantos aceptaria pagar comisión del 0.5%
# Sí, si aumenta conversión >10%: 36.7%
# Tal vez, según volumen: 26.7%
# Definitivamente sí: 26.7%
# Definitivamente no: 10.0%

# %% [markdown]
# # Paso 12: visualización de datos

# %% [markdown]
# A partir de este, son 4 puntos donde vamos estar graficando. ¿por que graficar? Una imagen vale mas que 1000 números. Las gráficas nos ayudan a ver patrones , comparar grupos facil mente y comunicar resultados a otros.

# %% [markdown]
# # Paso 12.1: Gráficas de barras horizontales

# %%
plt.figure(figsize=(10,5))
# contar cuantos eligieron cada funncionalidad
upsell_counts= df['P13_FuncionalidadUpsell'].value_counts()
# crear barars horizontales
sns.barplot(x=upsell_counts.values,y=upsell_counts.index,palette='viridis')
# colocacion de tidulos para el diagrama
plt.title('¿Que funcionalesdes del UPsell son más demandadas?')
plt.xlabel('Número de comercio')
plt.ylabel('Funcionalidad')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_8116/53121477.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=upsell_counts.values,y=upsell_counts.index,palette='viridis')

# %% [markdown]
# # 12.2 Gráfico circular (Pie Chart)

# %% [markdown]
# **¿Que muestra?**
# ¿Cuaánto están dispuestos a pagar los comercions?
# Se usa circular por que muestra parte de un todo   ( porcentajes).

# %%
plt.figure(figsize=(7,7))
# Calcular el porcentaje de cada
#COntar respuestas de precio
p_counts= df['P15_PrecioSaaS'].value_counts()
# COntar respuestas de precio
p_counts= df['P15_PrecioSaaS'].value_counts()
# Colores y explosion
colors=['#F6B8FF','#D0B8FF','#B8D9FF','#FFB8EA','#FFB8D0','#B8FFFB']
colors=colors[:len(p_counts)]
explode =[0.08 if i == 0 else 0 for i in range(len(p_counts))]
# Crear el gráfico circular
plt.pie(p_counts,labels=p_counts.index, autopct='%1.1f%%',startangle=140,colors=colors, explode=explode)
plt.title('¿Cuanto están dispuestos a pagar mesualmente?')
plt.tight_layout()
plt.show()
